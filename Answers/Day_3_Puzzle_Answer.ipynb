# %% [markdown]
# On your detachment field trip to the aquarium, Lt Humphrey decided he would rather stay in the bus and play on his new Steam deck so he wouldn't get eaten by any fishes. Unfortunately for him and for the bus driver, who was out on smoke break, his Steam deck ran out of batteries. Bored and unstimulated, he walked up to the gear shift of the bus and took out a pen and paper. Starting with the gear shift in the "upper left" position (Park), he pushed the gear shift a multitude of directions and wrote every push to a list, "pushes." This was lucky, because by the last push, the gear shaft snapped right off! In order to find out what gear the bus is in, you'll need to reconstruct each movement with a user-made "gear_shift" object. The following diagram represents each gear. What gear is the bus in?
#
#     P-----R
#     |     |
#     |     |
#     D-----N
#
#
# Your solution should make use of a Gear_Shift object which has attributes tracking its position after every push, and methods such as:
#
# ```
# def push(direction):
#   //something to interpret the text in "pushes"
#   //something to change the direction attribute(s)
# ```
#
# Answer should be a single capital letter.

# %%
import random

pushes = list()

for i in range(0, 100):
  match random.randint(0, 4):
    case(0):
      pushes.append("up")
    case(1):
      pushes.append("left")
    case(2):
      pushes.append("right")
    case(3):
      pushes.append("down")

print(pushes)

pushes = ['left', 'left', 'up', 'up', 'up', 'up', 'down', 'left', 'left', 'right', 'up', 'down', 'up', 'down', 'down', 'up', 'down', 'left', 'up', 'down', 'right', 'right', 'down', 'left', 'down', 'up', 'up', 'left', 'up', 'up', 'down', 'left', 'down', 'left', 'up', 'right', 'up', 'up', 'right', 'down', 'up', 'down', 'left', 'up', 'down', 'down', 'right', 'up', 'up', 'left', 'up', 'up', 'right', 'left', 'right', 'down', 'right', 'down', 'left', 'up', 'right', 'right', 'up', 'up', 'up', 'up', 'right', 'up', 'left', 'up', 'left', 'left', 'left', 'left', 'left', 'up', 'up', 'down', 'up']
# Out:
# ['left', 'left', 'up', 'up', 'up', 'up', 'down', 'left', 'left', 'right', 'up', 'down', 'up', 'down', 'down', 'up', 'down', 'left', 'up', 'down', 'right', 'right', 'down', 'left', 'down', 'up', 'up', 'left', 'up', 'up', 'down', 'left', 'down', 'left', 'up', 'right', 'up', 'up', 'right', 'down', 'up', 'down', 'left', 'up', 'down', 'down', 'right', 'up', 'up', 'left', 'up', 'up', 'right', 'left', 'right', 'down', 'right', 'down', 'left', 'up', 'right', 'right', 'up', 'up', 'up', 'up', 'right', 'up', 'left', 'up', 'left', 'left', 'left', 'left', 'left', 'left', 'up', 'down', 'up']

# %%
class Gear_Shift:
  horizontal_position = "left"
  vertical_position = "up"

  def __init__(self) -> None:
    pass

  def push(self, direction):
    match direction:
      case("up"):
        self.vertical_position = "up"
      case("down"):
        self.vertical_position = "down"
      case("left"):
        self.horizontal_position = "left"
      case("right"):
        self.horizontal_position = "right"

  def print_direction(self):
    if(self.horizontal_position == "left"):
      if(self.vertical_position == "up"):
        print("P")
      else:
        print("D")
    else:
      if(self.vertical_position == "up"):
        print("R")
      else:
        print("N")

# %%
stick = Gear_Shift()

for push in pushes:
  stick.push(push)

stick.print_direction()
# Out:
# P

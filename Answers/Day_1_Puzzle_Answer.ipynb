# %% [markdown]
# You are given a list of values, "change", which represents different children's amount of pocket change. If all the children listed are in a line for a fully stocked, 50¢ giant gumball machine, how many gumballs in total will be dispensed if no child shares his or her spare change with one another?
#
# For example, if there are two children, one who has \$1.25, and one who has \$0.75, if each gumball costs \$0.50, there would be a total of 3 gumballs dispensed, as the first child could purchase two, and the second only one, despite having cumulative change which could buy another gumball.
#
# Finally, how many more gumballs *max* could be bought if each child shared his or her change with each other / pooled their cash? In the previous example, since pooling their change would net them an extra gumball, the answer would be one. This is your puzzle answer to submit in the form!

# %%
# The "change" list has been populated for you.


change = [1.75, 1.65, 1.06, 2.50, 0.75, 0.25, 1.23, 1.25, 1.99, 0.50, 1.50, 1.25, 2.24, 1.25, 2.00, 0.75, 0.25, 0.10, 1.25, 1.24, 2.00, 0.75, 1.25, 2.50, 1.25, 1.75, 6.50, 1.50, 0.50, 3.00, 2.84, 2.50, 2.75, 2.01, 1.25, 1.35, 2.51, 1.25, 2.75, 1.25, 1.33, 1.00, 1.50, 0.75, 2.75, 2.45, 2.00, 1.50, 1.75, 0.75, 2.00, 0.50, 0.75, 3.00, 2.00, 2.50, 0.50, 2.00, 0.75, 0.50, 1.00, 2.50, 1.50, 1.00, 1.25, 2.75, 2.25, 3.00, 0.50, 1.75, 0.25, 2.25, 1.75, 2.75, 2.00, 1.25, 0.75, 3.00, 2.25, 2.25, 0.50, 1.50, 1.50, 0.25, 0.25, 2.00, 2.00, 1.25, 1.50, 2.75, 1.50, 3.00, 1.75, 3.00, 3.00, 2.25, 0.25, 0.25, 2.00, 2.75]

print(change[:5])
# Out:
# [1.75, 1.65, 1.06, 2.5, 0.75]

# %%
# NAIVE SOLUTION / EASIEST TO CODE

sum = 0
sharedSum = 0

for i in change:
  sum += int(i / 0.5)
  sharedSum += i

sharedSum = int(sharedSum / 0.5)

print(sharedSum - sum)
# Out:
# 28

# %%
# STUPID ONE-LINER SOLUTION FOR GOD-SWEAT PYTHON WIZARDS

import math
print (int(math.fsum([i for i in change])/0.5) - int(math.fsum([int(i / 0.5) for i in change])))
# Out:
# 28
